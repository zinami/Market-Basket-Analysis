# %%
# Import packages
import pandas as pd
import numpy as np
import datetime as dt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import matplotlib.pyplot as plt
import networkx as nx

import plotly.express as px
import plotly.graph_objects as go

# %%
# Import order product dataset
df = pd.read_csv('order_products.csv', usecols=['order_id', 'product_id'])
df.head()
# Out:
#    order_id  product_id
# 0        10          24
# 1        10          83
# 2        10          16
# 3        10          24
# 4        10          83

# %%
# Import product label mapping
products = pd.read_csv('products.csv')
products.head()
# Out:
#    product_id  department_id                product_name
# 0          61             19               cookies cakes
# 1         104             13           spices seasonings
# 2          94              7                         tea
# 3          38              1                frozen meals
# 4           5             13  marinades meat preparation

# %%
# Merge product labels
df = pd.merge(df, products, how='left', on='product_id').\
    drop(["product_id", "department_id"], axis=1)
df.head()
# Out:
#    order_id      product_name
# 0        10      fresh fruits
# 1        10  fresh vegetables
# 2        10       fresh herbs
# 3        10      fresh fruits
# 4        10  fresh vegetables

# %%
# Get modes and unique values
df.astype(object).describe()
# Out:
#         order_id  product_name
# count    2019501       2019501
# unique    200000           134
# top       790903  fresh fruits
# freq         137        226039

# %%
# Check product frequencies
df['product_name'].value_counts()
# Out:
# fresh fruits                  226039
# fresh vegetables              212611
# packaged vegetables fruits    109596
# yogurt                         90751
# packaged cheese                61502
#                                ...
# kitchen supplies                 561
# baby bath body care              515
# baby accessories                 504
# beauty                           387
# frozen juice                     279
# Name: product_name, Length: 134, dtype: int64

# %%
# Pivot the data - lines as orders and products as columns
pt = pd.pivot_table(df, index='order_id', columns='product_name', 
                    aggfunc=lambda x: 1 if len(x)>0 else 0).fillna(0)
pt.head()
# Out:
# product_name  air fresheners candles  asian foods  baby accessories  \
# order_id
# 10                               0.0          0.0               0.0
# 11                               0.0          0.0               0.0
# 28                               0.0          0.0               0.0
# 38                               0.0          0.0               0.0
# 56                               0.0          0.0               0.0
#
# product_name  baby bath body care  baby food formula  bakery desserts  \
# order_id
# 10                            0.0                1.0              0.0
# 11                            0.0                0.0              0.0
# 28                            0.0                0.0              0.0
# 38                            0.0                0.0              0.0
# 56                            0.0                0.0              0.0
#
# product_name  baking ingredients  baking supplies decor  beauty  \
# order_id
# 10                           0.0                    0.0     0.0
# 11                           0.0                    0.0     0.0
# 28                           0.0                    0.0     0.0
# 38                           0.0                    0.0     0.0
# 56                           0.0                    0.0     0.0
#
# product_name  beers coolers  ...  spreads  tea  tofu meat alternatives  \
# order_id                     ...
# 10                      0.0  ...      0.0  0.0                     0.0
# 11                      0.0  ...      0.0  0.0                     0.0
# 28                      0.0  ...      1.0  0.0                     0.0
# 38                      0.0  ...      0.0  0.0                     0.0
# 56                      0.0  ...      0.0  0.0                     0.0
#
# product_name  tortillas flat bread  trail mix snack mix  trash bags liners  \
# order_id
# 10                             0.0                  0.0                0.0
# 11                             0.0                  0.0                0.0
# 28                             0.0                  0.0                0.0
# 38                             0.0                  0.0                0.0
# 56                             0.0                  0.0                0.0
#
# product_name  vitamins supplements  water seltzer sparkling water  \
# order_id
# 10                             0.0                            0.0
# 11                             0.0                            0.0
# 28                             0.0                            0.0
# 38                             0.0                            0.0
# 56                             0.0                            0.0
#
# product_name  white wines  yogurt
# order_id
# 10                    0.0     0.0
# 11                    0.0     0.0
# 28                    0.0     1.0
# 38                    0.0     0.0
# 56                    0.0     0.0
#
# [5 rows x 134 columns]

# %%
# Check in how many orders was product yogurt sold
pt['fresh fruits'].sum()
# Out:
# 111199.0

# %%
# Apply the APRIORI algorithm to get frequent itemsets
# Rules supported in at least 5% of the transactions (more info at http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/)
frequent_itemsets = apriori(pt, min_support=0.05, use_colnames=True)
frequent_itemsets
#frequent_itemsets.sort_values(by='support').head()
# Out:
#       support                                           itemsets
# 0    0.076635                               (baking ingredients)
# 1    0.163865                                            (bread)
# 2    0.067765                                 (breakfast bakery)
# 3    0.074330                                           (butter)
# 4    0.069305                                  (candy chocolate)
# ..        ...                                                ...
# 151  0.051295         (yogurt, packaged vegetables fruits, milk)
# 152  0.051915  (packaged cheese, yogurt, packaged vegetables ...
# 153  0.062535  (fresh vegetables, packaged vegetables fruits,...
# 154  0.068325  (packaged cheese, fresh vegetables, packaged v...
# 155  0.076240  (yogurt, fresh vegetables, packaged vegetables...
#
# [156 rows x 2 columns]

# %%
# Generate the association rules - by confidence
rulesConfidence = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.50)
rulesConfidence.sort_values(by='confidence', ascending=False, inplace=True)
rulesConfidence.head()
# Out:
#                                            antecedents         consequents  \
# 65                         (fresh herbs, fresh fruits)  (fresh vegetables)
# 123  (yogurt, fresh vegetables, packaged vegetables...      (fresh fruits)
# 113  (fresh vegetables, milk, packaged vegetables f...      (fresh fruits)
# 34                                       (fresh herbs)  (fresh vegetables)
# 118  (packaged cheese, fresh vegetables, packaged v...      (fresh fruits)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 65             0.070135            0.444360  0.061815    0.881372  1.983463
# 123            0.087995            0.555995  0.076240    0.866413  1.558311
# 113            0.073075            0.555995  0.062535    0.855765  1.539159
# 34             0.093005            0.444360  0.078655    0.845707  1.903203
# 118            0.081970            0.555995  0.068325    0.833537  1.499180
#
#      leverage  conviction
# 65   0.030650    4.683872
# 123  0.027315    3.323711
# 113  0.021906    3.078336
# 34   0.037327    3.601205
# 118  0.022750    2.667284

# %%
# Generate the association rules - by lift
rulesLift = association_rules(frequent_itemsets, metric="lift", min_threshold=1.5)
rulesLift.sort_values(by='lift', ascending=False, inplace=True)
rulesLift.head()
# Out:
#                                     antecedents  \
# 28             (fresh vegetables, fresh fruits)
# 31                                (fresh herbs)
# 30                           (fresh vegetables)
# 29                  (fresh herbs, fresh fruits)
# 133  (packaged vegetables fruits, fresh fruits)
#
#                           consequents  antecedent support  consequent support  \
# 28                      (fresh herbs)            0.317560            0.093005
# 31   (fresh vegetables, fresh fruits)            0.093005            0.317560
# 30        (fresh herbs, fresh fruits)            0.444360            0.070135
# 29                 (fresh vegetables)            0.070135            0.444360
# 133        (yogurt, fresh vegetables)            0.269870            0.144660
#
#       support  confidence      lift  leverage  conviction
# 28   0.061815    0.194656  2.092964  0.032280    1.126221
# 31   0.061815    0.664642  2.092964  0.032280    2.034958
# 30   0.061815    0.139110  1.983463  0.030650    1.080121
# 29   0.061815    0.881372  1.983463  0.030650    4.683872
# 133  0.076240    0.282506  1.952899  0.037201    1.192122

# %% [markdown]
# #### Rules are of type `frozenset`, which is a Python built-in type that behaves similarly to sets except that it is immutable. Frozensets have functions to check if there are subsets, supersets, etc. More info at https://www.journaldev.com/22850/python-frozenset
#
#
# ### EXPLORE FREQUENT_ITEMSETS

# %%
# Add a column with the length
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

# Length=2 and Support>=0.2
frequent_itemsets[(frequent_itemsets['length'] == 2) & (frequent_itemsets['support'] >= 0.2)]
# Out:
#       support                                        itemsets  length
# 75   0.317560                (fresh vegetables, fresh fruits)       2
# 85   0.269870      (packaged vegetables fruits, fresh fruits)       2
# 100  0.234555  (packaged vegetables fruits, fresh vegetables)       2

# %%
len(frequent_itemsets[(frequent_itemsets['length'] == 2)])
# Out:
# 70

# %%
frequent_itemsets
# Out:
#       support                                           itemsets  length
# 0    0.076635                               (baking ingredients)       1
# 1    0.163865                                            (bread)       1
# 2    0.067765                                 (breakfast bakery)       1
# 3    0.074330                                           (butter)       1
# 4    0.069305                                  (candy chocolate)       1
# ..        ...                                                ...     ...
# 151  0.051295         (yogurt, packaged vegetables fruits, milk)       3
# 152  0.051915  (packaged cheese, yogurt, packaged vegetables ...       3
# 153  0.062535  (fresh vegetables, packaged vegetables fruits,...       4
# 154  0.068325  (packaged cheese, fresh vegetables, packaged v...       4
# 155  0.076240  (yogurt, fresh vegetables, packaged vegetables...       4
#
# [156 rows x 3 columns]

# %%
# Generate the association rules - by lift
rulesLift = association_rules(frequent_itemsets, metric="lift", min_threshold=0)
rulesLift.sort_values(by='confidence', ascending=False, inplace=True)
rulesLift.head()
# Out:
#                                            antecedents         consequents  \
# 190                        (fresh herbs, fresh fruits)  (fresh vegetables)
# 372  (yogurt, fresh vegetables, packaged vegetables...      (fresh fruits)
# 344  (fresh vegetables, milk, packaged vegetables f...      (fresh fruits)
# 87                                       (fresh herbs)  (fresh vegetables)
# 358  (packaged cheese, fresh vegetables, packaged v...      (fresh fruits)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 190            0.070135            0.444360  0.061815    0.881372  1.983463
# 372            0.087995            0.555995  0.076240    0.866413  1.558311
# 344            0.073075            0.555995  0.062535    0.855765  1.539159
# 87             0.093005            0.444360  0.078655    0.845707  1.903203
# 358            0.081970            0.555995  0.068325    0.833537  1.499180
#
#      leverage  conviction
# 190  0.030650    4.683872
# 372  0.027315    3.323711
# 344  0.021906    3.078336
# 87   0.037327    3.601205
# 358  0.022750    2.667284

# %%
rulesLift[(rulesLift['confidence']>=0.8)&(rulesLift['lift']>=1.5)]
# Out:
#                                            antecedents         consequents  \
# 190                        (fresh herbs, fresh fruits)  (fresh vegetables)
# 372  (yogurt, fresh vegetables, packaged vegetables...      (fresh fruits)
# 344  (fresh vegetables, milk, packaged vegetables f...      (fresh fruits)
# 87                                       (fresh herbs)  (fresh vegetables)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 190            0.070135            0.444360  0.061815    0.881372  1.983463
# 372            0.087995            0.555995  0.076240    0.866413  1.558311
# 344            0.073075            0.555995  0.062535    0.855765  1.539159
# 87             0.093005            0.444360  0.078655    0.845707  1.903203
#
#      leverage  conviction
# 190  0.030650    4.683872
# 372  0.027315    3.323711
# 344  0.021906    3.078336
# 87   0.037327    3.601205

# %%
rulesLift
# Out:
#                                            antecedents  \
# 190                        (fresh herbs, fresh fruits)
# 372  (yogurt, fresh vegetables, packaged vegetables...
# 344  (fresh vegetables, milk, packaged vegetables f...
# 87                                       (fresh herbs)
# 358  (packaged cheese, fresh vegetables, packaged v...
# ..                                                 ...
# 57                                      (fresh fruits)
# 247                                     (fresh fruits)
# 77                                      (fresh fruits)
# 81                                      (fresh fruits)
# 223                                     (fresh fruits)
#
#                                       consequents  antecedent support  \
# 190                            (fresh vegetables)            0.070135
# 372                                (fresh fruits)            0.087995
# 344                                (fresh fruits)            0.073075
# 87                             (fresh vegetables)            0.093005
# 358                                (fresh fruits)            0.081970
# ..                                            ...                 ...
# 57                       (hot dogs bacon sausage)            0.555995
# 247  (frozen produce, packaged vegetables fruits)            0.555995
# 77                          (soup broth bouillon)            0.555995
# 81                                      (spreads)            0.555995
# 223              (fresh vegetables, refrigerated)            0.555995
#
#      consequent support   support  confidence      lift  leverage  conviction
# 190            0.444360  0.061815    0.881372  1.983463  0.030650    4.683872
# 372            0.555995  0.076240    0.866413  1.558311  0.027315    3.323711
# 344            0.555995  0.062535    0.855765  1.539159  0.021906    3.078336
# 87             0.444360  0.078655    0.845707  1.903203  0.037327    3.601205
# 358            0.555995  0.068325    0.833537  1.499180  0.022750    2.667284
# ..                  ...       ...         ...       ...       ...         ...
# 57             0.084190  0.054425    0.097888  1.162698  0.007616    1.015184
# 247            0.066985  0.054415    0.097870  1.461067  0.017172    1.034235
# 77             0.083365  0.053880    0.096907  1.162446  0.007529    1.014996
# 81             0.078185  0.053560    0.096332  1.232101  0.010090    1.020081
# 223            0.065825  0.051445    0.092528  1.405664  0.014847    1.029425
#
# [386 rows x 9 columns]

# %%
data_scatter = dict(type='scatter',
    y=rulesLift['confidence'],
    x=rulesLift['lift'],
    #text=rulesLift.index,
    #mode='markers',
    #marker=dict(
    #size=rulesLift['support'],
    hovertemplate=#'Grand Prix: ' + df_racetracks["name_x"] + '<br>'
                    #'RuleID: ' + rulesLift.index + '<br>'+
                    'Lift: ' + rulesLift["lift"].astype(str) + '<br>'+
                    'Confidence: ' + rulesLift['confidence'].astype(str) + '<br>'+
                    'Support: ' + rulesLift['support'].astype(str) + '<br>'+    
                    'Antecedents: ' + rulesLift['antecedents'].astype(str) + '<br>'+
                    'Consequents: ' + rulesLift['consequents'].astype(str) + '<br>'
    '<extra></extra>',
    #color=scatterdf['Avg Salary'],  # set color equal to a variable
    #color_continuous_scale='mint',  # one of plotly colorscales
    #showscale=False,
    mode='markers',
    marker=dict(size=8,
                #size=rulesLift['support'],
                color=rulesLift['support'],
                colorscale='oranges',
                showscale=True,
                line_width=2),
    )
layout = dict(
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)',
    xaxis_title="Lift",
    yaxis_title="Confidence"
)

fig = go.Figure(data=data_scatter, layout=layout)
fig.add_hline(y=0.8, line_width=2, line_dash="dash", line_color="green")
fig.add_vline(x=1.5, line_width=2, line_dash="dash", line_color="green")
fig
# Out:
# <div>                            <div id="aca50b92-a87d-44ba-ada6-61fb92c612a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("

#
#      antecedent support  consequent support   support  confidence      lift  \
# 190            0.070135            0.444360  0.061815    0.881372  1.983463
# 372            0.087995            0.555995  0.076240    0.866413  1.558311
# 344            0.073075            0.555995  0.062535    0.855765  1.539159
# 87             0.093005            0.444360  0.078655    0.845707  1.903203
#
#      leverage  conviction
# 190  0.030650    4.683872
# 372  0.027315    3.323711
# 344  0.021906    3.078336
# 87   0.037327    3.601205

# %%
data_scatter = dict(type='scatter',
    y=rulesLift['confidence'],
    x=rulesLift['lift'],
    #text=rulesLift.index,
    #mode='markers',
    #marker=dict(
    #size=rulesLift['support'],
    hovertemplate=#'Grand Prix: ' + df_racetracks["name_x"] + '<br>'
                    #'RuleID: ' + rulesLift.index + '<br>'+
                    'Lift: ' + rulesLift["lift"].astype(str) + '<br>'+
                    'Confidence: ' + rulesLift['confidence'].astype(str) + '<br>'+
                    'Support: ' + rulesLift['support'].astype(str) + '<br>'+    
                    'Antecedents: ' + rulesLift['antecedents'].astype(str) + '<br>'+
                    'Consequents: ' + rulesLift['consequents'].astype(str) + '<br>'
    '<extra></extra>',
    #color=scatterdf['Avg Salary'],  # set color equal to a variable
    #color_continuous_scale='mint',  # one of plotly colorscales
    #showscale=False,
    mode='markers',
    marker=dict(size=8,
                #size=rulesLift['support'],
                color=rulesLift['support'],
                colorscale='oranges',
                showscale=True,
                line_width=2),
    )

layout = dict(
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)',
    xaxis_title="Lift",
    yaxis_title="Confidence"
)


fig = go.Figure(data=data_scatter,layout=layout)
fig.add_hline(y=0.5, line_width=2, line_dash="dash", line_color="green")
fig.add_vline(x=1.2, line_width=2, line_dash="dash", line_color="green")
# Out:
# <div>                            <div id="6c653ff2-8e82-4f93-8a92-a9924a690bd3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c653ff2-8e82-4f93-8a92-a9924a690bd3")) {                    Plotly.newPlot(                        "6c653ff2-8e82-4f93-8a92-a9924a690bd3",                        [{"hovertemplate": ["Lift: 1.9834630488968066<br>Confidence: 0.8813716404077849<br>Support: 0.061815<br>Antecedents: frozenset({'fresh herbs', 'fresh fruits'})<br>Consequents: frozenset({'fresh vegetables'})<br><extra></extra>", "Lift: 1.5583105322301343<br>Confidence: 0.8664128643672936<br>Support: 0.07624<br>Antecedents: frozenset({'yogurt', 'fresh vegetables', 'packaged vegetables fruits'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "Lift: 1.5391588510416072<br>Confidence: 0.8557646253848784<br>Support: 0.062535<br>Antecedents: frozenset({'fresh vegetables', 'milk', 'packaged vegetables fruits'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "Lift: 1.9032028536365408<br>Confidence: 0.8457072200419332<br>Support: 0.078655<br>Antecedents: frozenset({'fresh herbs'})<br>Consequents: frozenset({'fresh vegetables'})<br><extra></extra>", "Lift: 1.4991801360687924<br>Confidence: 0.8335366597535683<br>Support: 0.068325<br>Antecedents: frozenset({'packaged cheese', 'fresh vegetables', 'packaged vegetables fruits'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "Lift: 1.48754198457712<br>Confidence: 0.8270659057149559<br>Support: 0.10579<br>Antecedents: frozenset({'yogurt', 'packaged vegetables fruits'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "Lift: 1.4797903508567398<br>Confidence: 0.822756036124593<br>Support: 0.06696<br>Antecedents: frozenset({'packaged vegetables fruits', 'soy lactosefree'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "Lift: 1.4723318599906592<br>Confidence: 0.8186091524955066<br>Support: 0.11842<br>Antecedents: frozenset({'yogurt', 'fresh vegetables'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "Lift: 1.4641432357514863<br>Confidence: 0.8140563183616476<br>Support: 0.08745<br>Antecedents: frozenset({'packaged vegetables fruits', 'milk'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "Lift: 1.4610671815800538<br>Confidence: 0.812346047622602<br>Support: 0.054415<br>Antecedents: frozenset({'frozen produce', 'packaged vegetables fruits'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "Lift: 1.4572082593044609<br>Confidence: 0.8102005061319837<br>Support: 0.06243<br>Antecedents: frozenset({'packaged vegetables fruits', 'bread'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "Lift: 1.4450533079248045<br>Confidence: 0.8034424139396517<br>Support: 0.07562<br>Antecedents: frozenset({'fresh vegetables', 'soy lactosefree'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "Lift: 1.4421367643569025<br>Confidence: 0.8018208302986161<br>Support: 0.055045<br>Antecedents: frozenset({'packaged vegetables fruits', 'eggs'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "Lift: 1.4381678754484624<br>Confidence: 0.7996141479099679<br>Support: 0.06217<br>Antecedents: frozenset({'fresh vegetables', 'frozen produce'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "Lift: 1.4362371473373556<br>Confidence: 0.7985406727338331<br>Support: 0.09959<br>Antecedents: frozenset({'fresh vegetables', 'milk'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "Lift: 1.4307030647870536<br>Confidence: 0.7954637505062778<br>Support: 0.18658<br>Antecedents: frozenset({'fresh vegetables', 'packaged vegetables fruits'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "L ...

# %%
# Best Complementary products by Stregnth of Lift and Cofidence
rulesLift[(rulesLift['confidence']>=0.5)&(rulesLift['lift']>=1.2)].sort_values(by='support',ascending=False)
# Out:
#                             antecedents                   consequents  \
# 53                       (fresh fruits)            (fresh vegetables)
# 52                   (fresh vegetables)                (fresh fruits)
# 72         (packaged vegetables fruits)                (fresh fruits)
# 102        (packaged vegetables fruits)            (fresh vegetables)
# 103                  (fresh vegetables)  (packaged vegetables fruits)
# ..                                  ...                           ...
# 220        (fresh fruits, refrigerated)            (fresh vegetables)
# 333                      (yogurt, milk)  (packaged vegetables fruits)
# 183  (packaged vegetables fruits, eggs)            (fresh vegetables)
# 184            (fresh vegetables, eggs)  (packaged vegetables fruits)
# 15                 (canned meals beans)            (fresh vegetables)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 53             0.555995            0.444360  0.317560    0.571156  1.285346
# 52             0.444360            0.555995  0.317560    0.714646  1.285346
# 72             0.365415            0.555995  0.269870    0.738530  1.328304
# 102            0.365415            0.444360  0.234555    0.641887  1.444519
# 103            0.444360            0.365415  0.234555    0.527849  1.444519
# ..                  ...                 ...       ...         ...       ...
# 220            0.086430            0.444360  0.051445    0.595222  1.339503
# 333            0.095705            0.365415  0.051295    0.535970  1.466743
# 183            0.068650            0.444360  0.050675    0.738165  1.661186
# 184            0.084310            0.365415  0.050675    0.601056  1.644858
# 15             0.069705            0.444360  0.050435    0.723549  1.628295
#
#      leverage  conviction
# 53   0.070498    1.295670
# 52   0.070498    1.555978
# 72   0.066701    1.698112
# 102  0.072179    1.551576
# 103  0.072179    1.344030
# ..        ...         ...
# 220  0.013039    1.372702
# 333  0.016323    1.367551
# 183  0.020170    2.122097
# 184  0.019867    1.590660
# 15   0.019461    2.009906
#
# [116 rows x 9 columns]

# %% [markdown]
# # Subs

# %%
# Apply the APRIORI algorithm to get frequent itemsets
# Rules supported in at least 5% of the transactions (more info at http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/)
frequent_itemsetssub = apriori(pt, min_support=0.03, use_colnames=True)
frequent_itemsetssub.sort_values(by='support').head()
# Out:
#       support                                           itemsets
# 210  0.030060                            (yogurt, juice nectars)
# 129  0.030170                            (soy lactosefree, eggs)
# 239  0.030175                    (soy lactosefree, refrigerated)
# 370  0.030265  (yogurt, packaged vegetables fruits, bread, fr...
# 173  0.030290                     (packaged cheese, fresh herbs)

# %%
# Generate the association rules - by lift
rulesLift2 = association_rules(frequent_itemsetssub, metric="lift", min_threshold=0)
rulesLift2.sort_values(by='lift', ascending=True, inplace=True)
rulesLift2[rulesLift['lift']<=1]
# Out:
#                          antecedents                      consequents  \
# 203                   (fresh fruits)                    (soft drinks)
# 202                    (soft drinks)                   (fresh fruits)
# 197                   (fresh fruits)                    (paper goods)
# 196                    (paper goods)                   (fresh fruits)
# 266  (water seltzer sparkling water)               (fresh vegetables)
# 267               (fresh vegetables)  (water seltzer sparkling water)
# 317                           (milk)  (water seltzer sparkling water)
# 316  (water seltzer sparkling water)                           (milk)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 203            0.555995            0.087310  0.039585    0.071197  0.815447
# 202            0.087310            0.555995  0.039585    0.453384  0.815447
# 197            0.555995            0.063575  0.032090    0.057716  0.907847
# 196            0.063575            0.555995  0.032090    0.504758  0.907847
# 266            0.193005            0.444360  0.083355    0.431880  0.971915
# 267            0.444360            0.193005  0.083355    0.187584  0.971915
# 317            0.243325            0.193005  0.046610    0.191555  0.992485
# 316            0.193005            0.243325  0.046610    0.241496  0.992485
#
#      leverage  conviction
# 203 -0.008959    0.982652
# 202 -0.008959    0.812280
# 197 -0.003257    0.993782
# 196 -0.003257    0.896542
# 266 -0.002409    0.978033
# 267 -0.002409    0.993328
# 317 -0.000353    0.998206
# 316 -0.000353    0.997589

# %%
data_scatter = dict(type='scatter',
    y=rulesLift2['confidence'],
    x=rulesLift2['lift'],
    #text=rulesLift.index,
    #mode='markers',
    #marker=dict(
    #size=rulesLift['support'],
    hovertemplate=#'Grand Prix: ' + df_racetracks["name_x"] + '<br>'
                    #'RuleID: ' + rulesLift.index + '<br>'+
                    'Lift: ' + rulesLift2["lift"].astype(str) + '<br>'+
                    'Confidence: ' + rulesLift2['confidence'].astype(str) + '<br>'+
                    'Support: ' + rulesLift2['support'].astype(str) + '<br>'+    
                    'Antecedents: ' + rulesLift2['antecedents'].astype(str) + '<br>'+
                    'Consequents: ' + rulesLift2['consequents'].astype(str) + '<br>'
    '<extra></extra>',
    #color=scatterdf['Avg Salary'],  # set color equal to a variable
    #color_continuous_scale='mint',  # one of plotly colorscales
    #showscale=False,
    mode='markers',
    marker=dict(size=8,
                #size=rulesLift['support'],
                color=rulesLift2['support'],
                colorscale='oranges',
                showscale=True,
                line_width=2),
    )

layout = dict(
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)',
    xaxis_title="Lift",
    yaxis_title="Confidence"
)


fig = go.Figure(data=data_scatter,layout=layout)
fig.add_vline(x=1, line_width=2, line_dash="dash", line_color="red")
# Out:
# <div>                            <div id="fa5126a9-f29d-47c7-ad4e-db85e076d02f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa5126a9-f29d-47c7-ad4e-db85e076d02f")) {                    Plotly.newPlot(                        "fa5126a9-f29d-47c7-ad4e-db85e076d02f",                        [{"hovertemplate": ["Lift: 0.8154470670417143<br>Confidence: 0.07119668342341208<br>Support: 0.039585<br>Antecedents: frozenset({'fresh fruits'})<br>Consequents: frozenset({'soft drinks'})<br><extra></extra>", "Lift: 0.8154470670417144<br>Confidence: 0.45338449203985803<br>Support: 0.039585<br>Antecedents: frozenset({'soft drinks'})<br>Consequents: frozenset({'fresh fruits'})<br><extra></extra>", "Lift: